# %% [markdown]
# <h1> Adding <code>`frame_stride`</code> Functionality to <code>`VideoClips`</code>

# %%
from imports import *
from utils import *
from video_dataset import *

# %%
data_fs_1 = VideoDataset('../data/train', frames_per_clip=4, frame_stride=1)
data_fs_2 = VideoDataset('../data/train', frames_per_clip=4, frame_stride=2)
# Out:
# ...
# 100%|██████████| 1/1 [00:00<00:00,  1.33it/s]

# %%
plot_adjacent(data_fs_1[0][0], i=0, j=1, figsize=(10, 6), prefix='`frame_stride=1, ')
plot_adjacent(data_fs_1[0][0], i=2, j=3, figsize=(10, 6), prefix='`frame_stride=1, ')

# %%
plot_adjacent(data_fs_2[0][0], i=0, j=1, figsize=(10, 6), prefix='`frame_stride=2, ')
